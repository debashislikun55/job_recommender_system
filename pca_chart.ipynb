# %%
import pandas as pd
import numpy as np
import process_data as pda
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from itertools import cycle
import pickle 

topic_df, model, vec, topic_list = pda.process_data()

print(topic_list)
topic_df.to_pickle('topic_df.pkl')

def create_clusters():
    #topic_df, model, vec, topic_list = pda.process_data()
    pca = PCA(n_components=2)
    topic_df = pd.read_csv('topic_df.csv')
    #topic_df = pd.read_pickle('topic_df.pkl')
    X_train = topic_df.iloc[:, 1:-1]
    y_train = topic_df.iloc[:, -1]
    y_vals = y_train.unique()
    model = pca.fit(X_train)

    return X_train, model.transform(X_train), y_train, y_vals, model



def plot_PCA_2D(data, target, target_names, user_data):
    colors = cycle(['black','g','b','c','m','y','orange','w','aqua','yellow'])
    target_ids = range(len(target_names))
    plt.figure(figsize=(10,10))
    for i, c, label in zip(target_ids, colors, target_names):
        plt.scatter(data[target == i, 0], data[target == i, 1],
                   c=c, label=label, edgecolors='gray')
    plt.scatter(user_data[0][0], user_data[0][1], s = 150, color = 'red')
    plt.title('Job Clusters (You are the Red Dot)')
    plt.xlabel('Marketing Design Words')
    plt.ylabel('Project Management Words')
    plt.legend()

def transform_user_resume(pca_model, resume):
    '''
    take in resume and fit it according to both count vectorizer and PCA model
    '''
    jobs_df, topic_model, vec, topic_list = pda.process_data()
    vec = pickle.load(open('job_vec.sav', 'rb'))
    topic_model = pickle.load(open('topic_model.sav', 'rb'))

    doc = pda.tokenize_stem(resume)
    doc = vec.transform(doc)
    doc = topic_model.transform(doc)
    doc = pd.DataFrame(doc)
    X_train = doc.iloc[:, :-1]
    y_train = doc.iloc[:, -1]
    y_vals = y_train.unique()
    doc = pca_model.transform(doc)
    return doc
# Out:
# Topic  0
# sale, work, experi, manag, design, data, project, custom, market, product
#
# Topic  1
# design, data, ux, user, experi, ui, visual, product, interact, prototyp
#
# Topic  2
# design, ux, user, sale, ui, interact, custom, prototyp, product, insur
#
# Topic  3
# project, construct, manag, client, subcontractor, owner, bid, budget, cost, scope
#
# Topic  4
# client, consult, market, strategi, growth, firm, digit, strateg, clients, valu
#
# Topic  5
# market, campaign, content, email, media, brand, channel, social, advertis, execut
#
# Topic  6
# sale, construct, project, custom, roostifi, help, roof, solar, lend, understand
#
# Topic  7
# sale, clinic, consult, trial, diagnost, molecular, project, research, healthcar, biolog
#
# Topic  8
# product, roostifi, custom, clinic, account, lend, manag, trial, technic, client
#
# Topic  9
# diagnost, biolog, molecular, model, clinic, scientif, adivo, healthcar, consult, figur
#
# Topic  10
# client, birdey, estimates, bid, biolog, skill, diagnost, data, team, molecular
#
# Topic  11
# coursera, assist, product, skill, estimates, consult, learn, strong, bid, wish
#
# Topic  12
# coursera, client, learn, wish, end, experi, servic, machin, commerc, order
#
# Topic  13
# construct, adivo, consult, coursera, diagnost, custom, market, statu, healthcar, employ
#
# Topic  14
# model, custom, wish, commerc, figur, birdey, product, order, price, increas
#
# Topic  15
# coursera, roof, birdey, file, superintendent, awt, dropbox, reconstruct, capabl, order
#
# Topic  16
# coursera, birdey, figur, learn, model, skills, machin, build, customers, project
#
# Topic  17
# figur, servic, coursera, model, adivo, account, big, ux, mgr, dropbox
#
# Topic  18
# paypal, ux, account, financi, epic, real, medidata, licens, assist, game
#
# Topic  19
# slakey, brother, technic, consult, deloitt, experi, test, plumb, financi, paypal
# ['sale, work, experi, manag, design, data, project, custom, market, product', 'design, data, ux, user, experi, ui, visual, product, interact, prototyp', 'design, ux, user, sale, ui, interact, custom, prototyp, product, insur', 'project, construct, manag, client, subcontractor, owner, bid, budget, cost, scope', 'client, consult, market, strategi, growth, firm, digit, strateg, clients, valu', 'market, campaign, content, email, media, brand, channel, social, advertis, execut', 'sale, construct, project, custom, roostifi, help, roof, solar, lend, understand', 'sale, clinic, consult, trial, diagnost, molecular, project, research, healthcar, biolog', 'product, roostifi, custom, clinic, account, lend, manag, trial, technic, client', 'diagnost, biolog, molecular, model, clinic, scientif, adivo, healthcar, consult, figur', 'client, birdey, estimates, bid, biolog, skill, diagnost, data, team, molecular', 'coursera, assist, product, skill, estimates, consult, learn, strong, bid, wish', 'coursera, client, learn, wish, end, experi, servic, machin, commerc, order', 'construct, adivo, consult, coursera, diagnost, custom, market, statu, healthcar, employ', 'model, custom, wish, commerc, figur, birdey, product, order, price, increas', 'coursera, roof, birdey, file, superintendent, awt, dropbox, reconstruct, capabl, order', 'coursera, birdey, figur, learn, model, skills, machin, build, customers, project', 'figur, servic, coursera, model, adivo, account, big, ux, mgr, dropbox', 'paypal, ux, account, financi, epic, real, medidata, licens, assist, game', 'slakey, brother, technic, consult, deloitt, experi, test, plumb, financi, paypal']
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# left part :: recommendation.py ( 2 functions )
